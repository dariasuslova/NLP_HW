# %% [markdown]
# # Определение оценочной лексики с помощью Non-Negative  Matrix  Factorization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import NMF
from sklearn.externals import joblib
from sklearn import metrics
from tqdm import tqdm
from bs4 import BeautifulSoup
import gensim
from gensim.models import KeyedVectors
import re

# %% [markdown]
# ## 1) Подготовка текстов

# %%
file = open('/Users/Valeriya/Downloads/SentiRuEval_rest_train.xml')

# %%
soup = BeautifulSoup(file, 'lxml')

# %%
all_texts = []

# %%
for txt in soup.find_all('text'):
    all_texts.append(txt.text)

# %% [markdown]
# ## Preprocess data

# %%
raw_documents = []
snippets = []
for text in all_texts:
    raw_documents.append( text.lower() )
    snippets.append( text[0:min(len(text),100)] )
print("Read %d raw text documents" % len(raw_documents))
# Out:
# Read 19034 raw text documents

# %%
from nltk.tokenize import RegexpTokenizer
toker = RegexpTokenizer(r'((?<=[^\w\s])\w(?=[^\w\s])|(\W))+')

# %%
stopwords = open('stop.txt').read()

# %%
stopwords = stopwords.split('\n')

# %%
# create BoW + tf-idf model
from sklearn.feature_extraction.text import TfidfVectorizer


vectorizer = TfidfVectorizer(stop_words=stopwords, min_df=20)
A = vectorizer.fit_transform(raw_documents)
print( "Created %d X %d TF-IDF-normalized document-term matrix" % (A.shape[0], A.shape[1]) )

terms = vectorizer.get_feature_names()
joblib.dump((A,terms,snippets), "articles-tfidf.pkl")
# Out:
# Created 19034 X 11425 TF-IDF-normalized document-term matrix
# ['articles-tfidf.pkl']

# %%
# # top features from tf-idf model
# import operator


# sums = np.array(A.sum(axis=0)).ravel()
# # map weights to the terms
# weights = { term: sums[col] for col, term in enumerate(terms)}
# ranking = sorted(weights.items(), key=operator.itemgetter(1), reverse=True)
# for i, pair in enumerate( ranking[0:20] ):
#     print( "%s (%.2f)" % ( pair[0], pair[1] ) )

# %% [markdown]
# ## Apply NMF

# %%
(A,terms,snippets) = joblib.load( "articles-tfidf.pkl")

# create the model
k = 60
model = NMF( init="nndsvd", n_components=k ) 

W = model.fit_transform( A )
H = model.components_

# %%
tokenizer_tf = vectorizer.build_tokenizer()

# %%
# show topic descriptors
def get_descriptor(terms, H, topic_index, top):
    top_indices = np.argsort( H[topic_index,:] )[::-1]
    top_terms = []
    for term_index in top_indices[0:top]:
        top_terms.append( terms[term_index] )
    return top_terms

descriptors = []
for topic_index in range(k):
    descriptors.append( get_descriptor( terms, H, topic_index, 20) )
    str_descriptor = ", ".join( descriptors[topic_index] )
    print("Topic %02d: %s" % ( topic_index+1, str_descriptor))
# Out:
# Topic 01: вкус, соус, блюдо, соусом, люблю, чай, вполне, вроде, мясо, поэтому, пюре, тар, правда, сразу, десерт, мяса, порция, соусе, наверное, внутри
# Topic 02: кухня, отличная, понравилась, замечательная, вкусная, неплохая, прекрасная, японская, великолепная, итальянская, нравиться, отменная, отвратительная, высоте, хороша, порадовала, достойная, держать, европейская, неплохо
# Topic 03: свадьбу, гости, огромное, свадьбы, гостей, зал, праздник, свадьба, банкета, торт, праздновали, банкет, благодарность, отмечали, отдельное, праздника, выразить, еды, хотим, восторге
# Topic 04: принесли, кофе, счет, чай, заказали, официант, сразу, рублей, попросили, горячее, заказала, вместо, заказ, принести, сдачу, решили, итоге, официантка, заказал, оказалось
# Topic 05: место, замечательное, прекрасное, идеальное, уютное, лучшее, отдыха, самое, единственное, романтического, любимое, посидеть, чудесное, хочется, приятное, приличное, поесть, встреч, достойное, проведения
# Topic 06: понравилось, единственное, вчера, ждали, целом, правда, мужем, мило, брали, приходить, туалет, заказывали, оч, посидели, официант, друзьям, народу, принципе, придем, гостям
# Topic 07: вкусно, готовят, кормят, красиво, недорого, поесть, сытно, дорого, главное, отлично, люблю, правда, покушать, здорово, молодцы, приготовлено, ели, душевно, ресторанчик, поели
# Topic 08: пиво, вкусное, паб, гренки, пиву, свежее, колбаски, светлое, темное, закуски, пить, футбол, пшеничное, пивной, официантки, пивом, пабе, нефильтрованное, неплохое, вишневое
# Topic 09: еда, вкусная, нормальная, красивый, сытная, понравилась, свежая, вид, самая, поесть, напитки, качественная, вежливые, обслужили, маргарита, вообщем, еду, внимательный, 14, недорогая
# Topic 10: суши, роллы, вкусные, ролл, васаби, рис, бар, запеченные, роллов, мисо, филадельфия, угрем, запеченые, свежие, люблю, лососем, самые, японской, японский, городе
# Topic 11: вечер, провели, провести, отлично, прекрасный, огромное, вечера, проведенный, испорчен, удался, настроение, друзей, романтический, большое, компании, программа, добрый, шоу, благодарность, приятный
# Topic 12: обслуживание, быстрое, ненавязчивое, внимательное, прекрасное, ужасное, высоте, официантов, вежливое, отвратительное, плохое, медленное, великолепное, желать, доброжелательное, лучшего, навязчивое, нормальное, оставляет, хромает
# Topic 13: супер, держать, класс, молодцы, отличный, отлично, красиво, новый, свинина, респект, вечеринки, караоке, ура, слов, побольше, шоу, официантка, ребята, восторге, коктейли
# Topic 14: ресторан, лучший, любимый, замечательный, хороший, посетили, отличный, прекрасный, кухней, самый, уютный, пивной, данный, ходить, ресторанов, семьей, красивый, посещаю, посетить, понравился
# Topic 15: кафе, кофе, мороженое, случайно, небольшое, перекусить, гранд, интернет, зашла, маленькое, кухней, поэтому, уютное, находится, невском, посетителей, прийти, зайти, обычное, курят
# Topic 16: быстро, достаточно, обслуживают, готовят, заказ, приносят, обслужили, народу, роллы, обслуживали, вежливо, официантки, качественно, перекусить, приносили, вполне, еду, заказы, приняли, внимательно
# Topic 17: персонал, приветливый, вежливый, внимательный, обслуживающий, отличный, доброжелательный, дружелюбный, отзывчивый, приятный, замечательный, обходительный, прекрасное, улыбчивый, милый, заботливый, замечательная, вежлив, внимателен, приветлив
# Topic 18: меню, разнообразное, выбрать, официант, блюда, сайте, сразу, большое, интересное, порадовало, самое, блюд, таки, наличии, новое, написано, детское, официанта, выбрали, позиции
# Topic 19: атмосфера, приятная, уютная, домашняя, душевная, теплая, понравилась, потрясающая, располагает, главное, уюта, спокойная, располагающая, романтического, чудесная, дружелюбный, питере, дружелюбная, друзей, весьма
# Topic 20: минут, заказ, 15, 20, ждали, 40, ждать, 30, часа, официанта, заказа, час, пришлось, мин, официант, ушли, несли, ожидания, 45, 25
# Topic 21: остались, довольны, впечатления, гости, кухней, обслуживанием, мужем, отмечали, целом, приятные, положительные, юбилей, самые, сыты, посетили, атмосферой, заказали, прошло, интерьером, праздновали
# Topic 22: заведение, данное, заведении, посетить, милое, сие, посещать, посетили, замечательное, посещаю, посетил, людей, явно, достойное, данном, уютное, видимо, желание, ногой, которое
# Topic 23: нравится, хожу, люблю, приходится, бываю, ходим, ждать, правда, обожаю, захожу, бываем, мужем, караоке, регулярно, летом, сидеть, коктейли, периодически, заходим, роллы
# Topic 24: руб, счет, 150, 250, 100, 500, 200, рублей, стоит, 300, чек, 00, 50, 400, средний, 350, человека, 120, 180, 90
# Topic 25: отличное, отдыха, качество, класс, такого, место, мест, замечательная, приемлемые, вспоминаю, прекрасный, питер, молодцы, удачи, купчино, тихо, посиделок, вкусный, спокойно, довольна
# Topic 26: музыка, живая, приятная, играет, громкая, играла, фоновая, громко, ненавязчивая, вечером, понравилась, коктейли, минус, танцы, пятницу, отличная, сходить, потанцевать, порадовала, официантки
# Topic 27: официанты, вежливые, приветливые, внимательные, приятные, молодцы, работают, знают, ненавязчивые, доброжелательные, расторопные, администраторы, постоянно, хорошие, милые, вежливы, приносят, какие, готовят, мальчики
# Topic 28: уровне, высшем, высоком, хорошем, достойном, огромное, качество, должном, желаю, вполне, бываю, молодцы, восторге, впечатления, андрей, ребята, заведении, приятные, прошло, достаточно
# Topic 29: местечко, уютное, милое, замечательное, неплохое, кормят, тихое, обслуживают, бываю, прекрасное, кухню, маленькое, красивое, работы, советуем, спокойное, интересное, теплое, разнообразие, оригинальное
# Topic 30: выбор, блюд, большой, зал, компанией, минус, вин, горячих, напитков, огромный, плюс, коктейлей, оформление, подача, пал, закусок, ассортимент, зале, маленький, радует
# Topic 31: шашлык, хачапури, мясо, баранины, люля, свинины, харчо, сациви, кебаб, шашлыка, хинкали, овощи, мяса, вкусный, шашлыки, плов, свиной, чебуреки, телятины, заказали
# Topic 32: советую, посетить, никому, сходить, побывать, попробовать, ходить, класс, великолепная, пойду, прилично, пожалеете, высоте, замечательное, дорого, радует, дизайн, девушкой, вкусненько, общем
# Topic 33: пицца, пиццу, пиццы, паста, тесто, пасту, хат, вкусная, самая, сыра, понравилась, пицце, доставка, заказали, часа, начинки, тесте, италии, дом, привезли
# Topic 34: интерьер, приятный, понравился, уютный, интересный, красивый, милый, спокойный, стильный, удобные, неплохой, стиле, замечательный, особо, вроде, зашли, ценник, вообщем, необычный, светлый
# Topic 35: заведения, могу, кухни, одно, хочется, городе, сюда, мест, кухню, стоит, такого, лучших, обслуживания, качество, заведении, либо, отзыв, бар, поэтому, ресторанов
# Topic 36: цены, вполне, приемлемые, демократичные, высокие, завышены, качество, качества, низкие, средние, соотношение, умеренные, радуют, соответствуют, приемлимые, рублей, нормальные, гуманные, адекватные, доступные
# Topic 37: пива, попить, паб, выпить, сортов, бар, футбол, паба, выбор, пивной, сорта, разливного, посмотреть, пиву, гренки, колбаски, ассортимент, пару, пабе, работает
# Topic 38: суп, крем, грибной, вкусный, томатный, супа, тыквенный, пюре, луковый, острый, понравился, лососем, грибов, мисо, чай, второе, шпината, морепродуктов, обед, супе
# Topic 39: уютно, мило, спокойно, тепло, тихо, домашнему, чисто, достаточно, комфортно, посидеть, кофе, места, приятные, душевно, красиво, покушать, дома, быстрое, здорово, просторно
# Topic 40: хорошее, достаточно, качество, плохо, общем, настроение, нормальные, впечатление, сюда, главное, приятный, бываем, приличная, минусов, места, готовят, вполне, спокойное, роллы, качественная
# Topic 41: обстановка, уютная, приятная, спокойная, домашняя, вежливый, отлично, отличная, понравилась, замечательный, замечательное, расслабляющая, респект, располагает, теплая, вкусное, места, романтическая, рождение, великолепная
# Topic 42: ресторане, вашем, новый, отметить, отзывы, блюда, мужем, побывали, добрый, решили, администратор, впечатление, блюдо, такого, испорчено, вчера, любом, данном, горячее, рыбу
# Topic 43: рождения, отмечали, свой, отмечала, дня, отметить, др, рождение, друга, праздновала, подруги, праздник, юбилей, отмечал, большое, программа, новый, компанией, человека, караоке
# Topic 44: столик, девушка, официантка, стол, администратор, пришли, зале, решили, заранее, зал, никто, 00, сразу, заказали, итоге, входе, пришлось, вопрос, попросили, заказ
# Topic 45: рекомендую, попробовать, отличная, пожалеете, хороши, общем, любителям, посетить, настоятельно, шоу, ресторанчик, шикарный, однозначно, питере, раза, обслуживанием, десерт, бываем, качественно, прекрасное
# Topic 46: бизнес, ланч, рублей, ланчи, обед, ланча, днем, ланче, обеда, ланчем, стоит, цена, ланчей, борщ, 250, пообедать, ходим, второе, вполне, причем
# Topic 47: 10, баллов, 12, ставлю, оценка, качество, чаевых, цена, 11, оценки, класс, скидку, мин, штрудель, минут, 07, кухню, нём, скидка, хочу
# Topic 48: выше, похвал, всяких, всяческих, среднего, огромное, здорово, стейк, торт, вне, посещения, моему, респект, мальчики, лучший, мнению, звук, оближешь, десерт, рту
# Topic 49: вино, вина, официант, бокал, домашнее, бутылку, красное, белое, сомелье, вин, бокалам, закуски, салаты, горячее, десерт, стейк, карта, десерты, вином, паста
# Topic 50: вкусные, блюда, салаты, самые, свежие, роллы, горячие, десерты, закуски, коктейли, понравились, супы, красиво, мясные, приготовленные, качественные, напитки, заказанные, заказывали, некоторые
# Topic 51: обязательно, придем, приду, питере, зайду, вернемся, зайдем, посетим, вчера, сюда, придём, попробовать, вернусь, отдельное, подругой, огромное, загляну, друзьям, следующий, вкусный
# Topic 52: салат, цезарь, стейк, креветками, понравился, вкусный, салата, горячее, курицей, греческий, салате, печенью, теплый, куриной, говядины, авокадо, оливье, листья, соусом, тунцом
# Topic 53: сервис, хороший, отличный, высоте, ненавязчивый, оценка, отлично, ужасный, хорошие, минус, отвратительный, пойду, хромает, классный, средне, знаю, харбин, тихий, кухню, еду
# Topic 54: друзьями, посидеть, бар, коктейли, ходим, посидели, отдохнуть, хожу, спокойно, вечером, пообщаться, сюда, посиделок, семьей, поболтать, весело, коктейлей, ходили, друзья, зашли
# Topic 55: ресторана, посещения, шеф, сотрудникам, хочу, благодарность, коллективу, повара, гостей, большое, уровня, такого, вид, персоналу, вашего, выразить, уважаемые, блюда, повару, администрация
# Topic 56: приятное, впечатление, целом, осталось, общее, самое, оставил, положительное, общем, понравились, первое, оставляет, вполне, производит, благоприятное, посещения, сложилось, оставило, навязчивое, ощущение
# Topic 57: вообще, ужасно, общем, официантки, ужас, молчу, какие, знаю, ощущение, вроде, отвратительное, самое, никакого, понятно, никто, никакой, нормально, раза, отвратительная, ужасное
# Topic 58: приятно, удивлены, посидеть, зайти, удивлена, провести, удивил, удивили, удивлен, удивило, районе, мелочь, выпить, общем, поужинать, удивила, восторге, сразу, кофе, отметить
# Topic 59: порции, большие, маленькие, огромные, двоих, ценник, минус, небольшие, китайских, салаты, съесть, горячего, нормальные, единственный, десерт, ресторанах, сытные, горячее, приличные, брали
# Topic 60: хорошая, кухня, хороший, компания, вытяжка, неплохой, вентиляция, девушкой, частенько, милый, комната, понравились, молодые, правда, приветливые, вид, субботу, хорошим, заказывать, паб

# %%
from pymystem3 import Mystem
import collections
from collections import Counter, defaultdict
c = Counter()

# %%
m = Mystem()

# %%
lemmatized_descriptors = []
for arr in descriptors:
    for word in arr:
        lemma = m.lemmatize(word)[0]
        lemmatized_descriptors.append(lemma)

# %% [markdown]
# ## 3) Получили дескрипторы. Теперь открываем w2v модель

# %%
vectors = KeyedVectors.load_word2vec_format('/Users/Valeriya/Desktop/ruscorpora_mean_hs.model.bin', binary=True)

# %%
## 4) basic_words - просто ручной список слов, которые на наш взгляд очень оценочно окрашены

# %%
basic_words = ['красивый_A', 'вкусный_A', 'прекрасный_A', 'качественный_A', 'ужасный_A', 'отвратительный_A',
              'мерзкий_A',  'советовать_V', 'рекомендовать_V', 'ужасно_ADV', 'нравиться_V', 'прекрасно_ADV', 'ужас_S',
              'радость_S', 'уютный_A', 'испорченный_A', 'несвежий_A', 'хороший_A', 'плохой_A']

# %%
mean = sum([vectors[i] for i in basic_words])/len(basic_words)

# %% [markdown]
# ### mean - средний вектор по этим словам

# %%
words_with_pos = []
for word in lemmatized_descriptors:
    if word+'_S' in vectors:
        words_with_pos.append(word+'_S')
    elif word+'_A' in vectors:
        words_with_pos.append(word+'_A')
    elif word+'_V' in vectors:
        words_with_pos.append(word+'_V')
    elif word+'_ADV' in vectors:
        words_with_pos.append(word+'_ADV')
    elif word+'_APRO' in vectors:
        words_with_pos.append(word+'_APRO')
    else:
        print(word) # то, что не нашлось в модели - но там и не очень нужные слова
# Out:
# вроде
# поэтому
# вместо
# оч
# есть
# 14
# запеченый
# ура
# много
# поэтому
# таки
# 15
# 20
# 40
# 30
# 45
# 25
# сие
# который
# 150
# 250
# 100
# 500
# 200
# 300
# 00
# 50
# 400
# 350
# 120
# 180
# 90
# такой
# какой
# никто
# вроде
# один
# такой
# либо
# поэтому
# второй
# такой
# свой
# никто
# 00
# раз
# 250
# второй
# причем
# 10
# 12
# 11
# 07
# он
# мой
# некоторые
# такой
# первый
# какой
# вроде
# никто
# раз
# двое

# %%
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import cosine

# %% [markdown]
# ## 5) Сравниваем каждое слово из words_with_pos с каждыс словом из basic_words, рассчитываем дальность (cosine distance),  если она меньше 0.9, вносим слово в список оценочных

# %%
final_list = []
count=0
from scipy.spatial import distance
for word in words_with_pos:
    for gold in basic_words:
        vec_descr = vectors[word]
        vec_gold= vectors[gold]
        
    if cosine(vec_descr, vec_gold) < 0.9:
        final_list.append(word)

# %%
len(set(final_list))
# Out:
# 93

# %%
len(set(final_list)), len(set(words_with_pos))
# Out:
# (93, 484)

# %%
final = set(final_list)

# %%
final #непосредственно сам итоговый лист
# Out:
# {'адекватный_A',
#  'благоприятный_A',
#  'большой_A',
#  'вежливый_A',
#  'великолепный_A',
#  'видимо_ADV',
#  'вкус_S',
#  'вкусно_ADV',
#  'вкусный_A',
#  'вообще_ADV',
#  'всякий_APRO',
#  'выбирать_V',
#  'высокий_A',
#  'главное_S',
#  'гуманный_A',
#  'демократичный_A',
#  'доброжелательный_A',
#  'добрый_A',
#  'довольный_A',
#  'дорого_ADV',
#  'достойный_A',
#  'дружелюбный_A',
#  'единственный_A',
#  'желать_V',
#  'завышать_V',
#  'замечательный_A',
#  'здорово_ADV',
#  'идеальный_A',
#  'интересный_A',
#  'испортить_V',
#  'испорченный_A',
#  'качественный_A',
#  'качество_S',
#  'классный_A',
#  'комфортно_ADV',
#  'красивый_A',
#  'любимый_S',
#  'мило_ADV',
#  'молодой_A',
#  'наверное_ADV',
#  'навязчивый_A',
#  'написать_V',
#  'настроение_S',
#  'необычный_A',
#  'неплохо_ADV',
#  'неплохой_A',
#  'низкий_A',
#  'новое_S',
#  'нормальный_A',
#  'нравиться_V',
#  'обходительный_A',
#  'общий_A',
#  'обычный_A',
#  'оказываться_V',
#  'оригинальный_A',
#  'отвратительный_A',
#  'отзывчивый_A',
#  'отличный_A',
#  'отменный_A',
#  'плохо_ADV',
#  'плохой_A',
#  'пожалеть_V',
#  'положительный_A',
#  'понравиться_V',
#  'понятно_ADV',
#  'порадовать_V',
#  'прекрасный_A',
#  'приемлемый_A',
#  'приемлимый_A',
#  'приличный_A',
#  'приятно_ADV',
#  'приятный_A',
#  'работать_V',
#  'радовать_V',
#  'разнообразный_A',
#  'расторопный_A',
#  'рекомендовать_V',
#  'рождение_S',
#  'соответствовать_V',
#  'стильный_A',
#  'уважаемый_A',
#  'удивлять_V',
#  'удобный_A',
#  'ужасный_A',
#  'умеренный_A',
#  'фоновый_A',
#  'хороший_A',
#  'хотеть_V',
#  'хотеться_V',
#  'хромать_V',
#  'частенько_ADV',
#  'чудесный_A',
#  'шикарный_A'}

# %% [markdown]
# # Итого получилось 93 слова

# %% [markdown]
# ### 6) Находим коллокации слов из final_list

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.collocations import *
bigram_measures = nltk.collocations.BigramAssocMeasures()
trigram_measures = nltk.collocations.TrigramAssocMeasures()

# %%
tokens = []
for arr in all_texts:
    words = word_tokenize(arr)
    for w in words:
        lemma = m.lemmatize(w)
        tokens.append(lemma)

# %%
tokens_clear = [arr[0] for arr in tokens]

# %%
finder = BigramCollocationFinder.from_words(tokens_clear)
# # only bigrams that appear 3+ times

# %%
words_for_filter = []
for word in set(final_list):
    word = re.sub('_.*', '', word)
#     creature_filter = lambda *w: word not in w
    words_for_filter.append(word)

# %%
def create_filter_minfreq_inwords(scored, words, minfreq):
    def bigram_filter(w1, w2):
        return (w1 not in words and w2 not in words) and (
                (w1, w2) in scored and scored[w1, w2] <= minfreq)
    return bigram_filter

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
scored = dict(finder.score_ngrams(bigram_measures.raw_freq))

# %%
myfilter = create_filter_minfreq_inwords(scored, words_for_filter, 5)

# %%
# sorted(words_for_filter)

# %%
finder.apply_ngram_filter(myfilter)
print(finder.nbest(bigram_measures.likelihood_ratio, 100))
# Out:
# [('в', 'общий'), ('день', 'рождение'), ('очень', 'понравиться'), ('молодой', 'человек'), ('очень', 'вкусно'), ('очень', 'вкусный'), ('оставаться', 'довольный'), ('высокий', 'уровень'), ('приятно', 'удивлять'), ('хотеться', 'бы'), ('очень', 'приятный'), ('мой', 'любимый'), ('всякий', 'похвала'), ('не', 'понравиться'), ('очень', 'довольный'), ('понравиться', '.'), ('не', 'пожалеть'), ('очень', 'хороший'), ('высоко', 'всякий'), ('не', 'хотеться'), ('самый', 'главное'), ('вкусно', ',\n'), ('общий', ',\n'), ('очень', 'нравиться'), ('вкусный', 'еда'), ('по', 'вкус'), ('на', 'вкус'), ('большой', 'количество'), ('я', 'понравиться'), ('оставлять', 'желать'), ('общий', 'впечатление'), ('добрый', 'день'), ('на', 'высокий'), ('вкусно', '.'), ('единственный', 'минус'), ('положительный', 'эмоция'), ('наверное', ',\n'), ('отличный', 'место'), ('.', 'единственный'), ('вкусный', ',\n'), ('очень', 'приятно'), ('большой', 'спасибо'), ('большой', 'компания'), ('не', 'плохой'), ('фоновый', 'музыка'), ('желать', 'хороший'), ('всякий', 'случай'), ('понравиться', ',\n'), ('приятный', 'впечатление'), ('самый', 'вкусный'), ('со', 'вкус'), (',\n', 'наверное'), ('мой', 'вкус'), ('вкусно', '!'), ('приятный', 'атмосфера'), (',\n', 'видимо'), ('самый', 'хороший'), ('очень', 'порадовать'), ('хотеть', 'выражать'), ('в', 'качество'), ('хотеть', 'отмечать'), ('видимо', ',\n'), ('хороший', 'место'), ('порция', 'большой'), ('все', 'понравиться'), ('вкусно', 'поесть'), ('довольный', '.'), ('не', 'плохо'), ('не', 'хотеть'), ('я', 'нравиться'), ('не', 'навязчивый'), ('вообще', 'не'), ('хотеть', 'сказать'), ('вполне', 'приличный'), ('вкусно', 'и'), ('положительный', 'отзыв'), ('очень', 'красивый'), ('очень', 'достойный'), ('большой', 'выбор'), ('любой', 'вкус'), ('хотеться', 'отмечать'), ('качество', 'еда'), ('не', 'соответствовать'), ('написать', 'отзыв'), ('еда', 'вкусный'), ('испортить', 'настроение'), ('вкусный', '.'), ('вкус', '.'), ('большой', 'порция'), ('хотеть', 'поблагодарить'), ('вежливый', 'и'), ('удобный', 'диван'), ('а', 'главное'), ('хороший', ',\n'), ('неплохой', ',\n'), ('самый', 'интересный'), ('понятно', ',\n'), ('замечательный', 'место'), ('вкусовой', 'качество'), ('настоятельно', 'рекомендовать')]

# %% [markdown]
# ## 7) Наконец, сравним наш список из 92 слов со словарем

# %%
sentilex = open('/Users/Valeriya/Downloads/rusentilex.txt').read()

# %%
sentilex_words = []
for item in sentilex.split('\n'):
    words = item.split(',')
    sentilex_words.append(words[0])

# %%
found_in_sentilex = []

# %%
for word in words_for_filter:
    if word in sentilex_words:
        found_in_sentilex.append(word)

# %%
len(set(found_in_sentilex))
# Out:
# 49

# %% [markdown]
# # Совпадение с Сентилексом - 49 слов!

# %%
found_in_sentilex
# Out:
# ['адекватный',
#  'низкий',
#  'удобный',
#  'прекрасный',
#  'радовать',
#  'интересный',
#  'добрый',
#  'приемлемый',
#  'оригинальный',
#  'положительный',
#  'приличный',
#  'гуманный',
#  'обходительный',
#  'великолепный',
#  'отвратительный',
#  'стильный',
#  'классный',
#  'пожалеть',
#  'красивый',
#  'нормальный',
#  'отзывчивый',
#  'испортить',
#  'идеальный',
#  'довольный',
#  'расторопный',
#  'неплохой',
#  'хороший',
#  'завышать',
#  'достойный',
#  'ужасный',
#  'доброжелательный',
#  'замечательный',
#  'приятный',
#  'качественный',
#  'нравиться',
#  'шикарный',
#  'отличный',
#  'отменный',
#  'демократичный',
#  'вкусный',
#  'умеренный',
#  'плохой',
#  'дружелюбный',
#  'благоприятный',
#  'навязчивый',
#  'понравиться',
#  'вежливый',
#  'любимый',
#  'чудесный']
